# %% [markdown]
# # Data Visualization and Charts
#
# 1. Introduction
#
# Objective: Briefly introduce the purpose of the assignment, emphasizing the importance of data visualization in communicating complex information.
#
# Dataset Overview: Provide a short description of the Iris dataset, including its source, variables (sepal length, sepal width, petal length, petal width, species), and its significance in data science.

# %% [markdown]
# 2. Dataset Preparation
#
# Data Loading: Instructions on loading the Iris dataset using Python (e.g., pandas.read_csv or sns.load_dataset('iris') if using Seaborn).
#
# Data Inspection: Initial exploration of the dataset to understand its structure, using methods like .head(), .describe(), and .info().

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 3. Data Visualization Creation
#
# Bar Chart: Create a bar chart showing the average size (length and width) of sepals and petals for each Iris species.
#
#
# Python Libraries: Matplotlib or Seaborn.
#
# Code Snippet: Provide the Python code for generating the bar chart.
#
# Evaluation: Discuss the clarity and simplicity of the bar chart.
#
# Line Chart: Plot the variation of sepal length across different samples, sorted by sepal length.
#
#
# Python Libraries: Matplotlib.
#
# Code Snippet: Include the Python code for the line chart.
#
# Evaluation: Evaluate the line chart based on consistency and effectiveness in showing trends.
#
# Scatter Plot: Visualize the relationship between petal length and petal width, colored by species.
#
#
# Python Libraries: Seaborn for its built-in hue parameter.
#
# Code Snippet: Provide the Python code.
#
# Evaluation: Identify areas for improvement, focusing on clarity and the ability to distinguish between species.
#
# Histogram: Display the distribution of sepal widths across all samples.
#
#
# Python Libraries: Matplotlib or Seaborn.
#
# Code Snippet: Include the Python code.
#
# Evaluation: Discuss the histogram's effectiveness in showing distribution and identify improvement areas based on simplicity and readability.

# %% [markdown]
# 4. Visualization Improvement
#
# Improvement Strategies: Based on the evaluation, outline specific strategies to improve each visualization (e.g., adjusting scales, simplifying color schemes, adding labels).
#
# Revised Visualizations: Apply the improvement strategies and present the revised visualizations with Python code.

# %% [markdown]
# 5. Final Report Creation
#
# Audience Identification: Define the specific audience for your report (e.g., data science students, biologists).
#
# Report Structure: Outline the structure of your report, including an introduction to the dataset, key insights from the visualizations, and conclusions.
#
# Language and Visual Cues: Discuss how you tailored the language and visual cues to suit your identified audience

# %% [markdown]
# ## References
#
# APA Style: List all references, including the Iris dataset source, Python libraries documentation, and any other resources consulted, in APA style.
